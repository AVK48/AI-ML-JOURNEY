# %% [markdown]
# <a href="https://colab.research.google.com/github/AVK48/AI-ML-JOURNEY/blob/pandas/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/employees (1).csv')

# %%
df
# Out:
#    emp_id     name department        salary   join_date       city
# 0     101    Alice         HR         52000  2022-03-15     Mumbai
# 1     102      Bob       Tech         85000  2021-07-01       Pune
# 2     103  Charlie       Tech           NaN  2020-11-20     Mumbai
# 3     104    Diana         HR         48000         NaN      Delhi
# 4     105      Eve    Finance         73000  2023-01-10        NaN
# 5     106      bob       Tech         85000  2021-07-01       Pune
# 6     107    Frank       Tech  not_a_number  2022-06-01  Bangalore

# %%
df.head(3)
# Out:
#    emp_id     name department salary   join_date    city
# 0     101    Alice         HR  52000  2022-03-15  Mumbai
# 1     102      Bob       Tech  85000  2021-07-01    Pune
# 2     103  Charlie       Tech    NaN  2020-11-20  Mumbai

# %%
df.tail(6)
# Out:
#    emp_id     name department        salary   join_date       city
# 1     102      Bob       Tech         85000  2021-07-01       Pune
# 2     103  Charlie       Tech           NaN  2020-11-20     Mumbai
# 3     104    Diana         HR         48000         NaN      Delhi
# 4     105      Eve    Finance         73000  2023-01-10        NaN
# 5     106      bob       Tech         85000  2021-07-01       Pune
# 6     107    Frank       Tech  not_a_number  2022-06-01  Bangalore

# %%
df.head(3)
df.tail(3)
# Out:
#    emp_id   name department        salary   join_date       city
# 4     105    Eve    Finance         73000  2023-01-10        NaN
# 5     106    bob       Tech         85000  2021-07-01       Pune
# 6     107  Frank       Tech  not_a_number  2022-06-01  Bangalore

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (7, 6)

# %%
df.columns
# Out:
# Index(['emp_id', 'name', 'department', 'salary', 'join_date', 'city'], dtype='object')

# %%
df.columns[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1919/2249767175.py in <cell line: 0>()
# ----> 1 df.columns[7]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5387             # GH#44051 exclude bool, which would return a 2d ndarray
#    5388             key = com.cast_scalar_indexer(key)
# -> 5389             return getitem(key)
#    5390
#    5391         if isinstance(key, slice):
#
# IndexError: index 7 is out of bounds for axis 0 with size 6

# %%
df.columns[5]
# Out:
# 'city'

# %%
df.dtypes
# Out:
# emp_id         int64
# name          object
# department    object
# salary        object
# join_date     object
# city          object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
type(df['salary'])  #single square bracket prints the type series
# Out:
# pandas.core.series.Series

# %%
type(df[['salary']])  #double square brackets prints the type dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df[['name','salary']] #only needed from the list (name,salary)
# Out:
#       name        salary
# 0    Alice         52000
# 1      Bob         85000
# 2  Charlie           NaN
# 3    Diana         48000
# 4      Eve         73000
# 5      bob         85000
# 6    Frank  not_a_number

# %%
df[['department','city']]
# Out:
#   department       city
# 0         HR     Mumbai
# 1       Tech       Pune
# 2       Tech     Mumbai
# 3         HR      Delhi
# 4    Finance        NaN
# 5       Tech       Pune
# 6       Tech  Bangalore

# %%
df[['city','name']]
# Out:
#         city     name
# 0     Mumbai    Alice
# 1       Pune      Bob
# 2     Mumbai  Charlie
# 3      Delhi    Diana
# 4        NaN      Eve
# 5       Pune      bob
# 6  Bangalore    Frank

# %% [markdown]
# Dictionary to DataFrame

# %%
data = {'Name':['jai','princi','guarv','av'],  #coverting dictionary to the data frame
        'age':[23,34,54,54],
        'address': ['wgl','hyd','krmg','viy']}
df2=pd.DataFrame(data)
df2
# Out:
#      Name  age address
# 0     jai   23     wgl
# 1  princi   34     hyd
# 2   guarv   54    krmg
# 3      av   54     viy

# %%
type(df2) #type of the variable
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Age Inspection

# %%
df2.age # same as df2['age']
# Out:
# 0    23
# 1    34
# 2    54
# 3    54
# Name: age, dtype: int64

# %%
ages = df2.age
ages
# Out:
# 0    23
# 1    34
# 2    54
# 3    54
# Name: age, dtype: int64

# %%
ages.mean()
# Out:
# np.float64(41.25)

# %%
ages.describe()
# Out:
# count     4.000000
# mean     41.250000
# std      15.392098
# min      23.000000
# 25%      31.250000
# 50%      44.000000
# 75%      54.000000
# max      54.000000
# Name: age, dtype: float64

# %% [markdown]
# read_csv

# %%
df3 = pd.read_csv('/content/employees (1).csv',sep= '/t') #comma sepreated data
# Out:
# /tmp/ipykernel_1919/2451874851.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df3 = pd.read_csv('/content/employees (1).csv',sep= '/t')

# %%
df3
# Out:
#        emp_id,name,department,salary,join_date,city
# 0              101,Alice,HR,52000,2022-03-15,Mumbai
# 1                102,Bob,Tech,85000,2021-07-01,Pune
# 2               103,Charlie,Tech,,2020-11-20,Mumbai
# 3                         104,Diana,HR,48000,,Delhi
# 4                 105,Eve,Finance,73000,2023-01-10,
# 5                106,bob,Tech,85000,2021-07-01,Pune
# 6  107,Frank,Tech,not_a_number,2022-06-01,Bangalore

# %%
df3 = pd.read_csv('/content/employees (1).csv',sep= ',',usecols=['emp_id','salary','name'],dtype={"emp_id":str})

# %%
df3
# Out:
#   emp_id     name        salary
# 0    101    Alice         52000
# 1    102      Bob         85000
# 2    103  Charlie           NaN
# 3    104    Diana         48000
# 4    105      Eve         73000
# 5    106      bob         85000
# 6    107    Frank  not_a_number

# %%
df3.describe()
# Out:
#        emp_id   name salary
# count       7      7      6
# unique      7      7      5
# top       101  Alice  85000
# freq        1      1      2

# %% [markdown]
# Filtering

# %%
df2[df2['age']>20] #for getting bigger than age 20
# Out:
#      Name  age address
# 0     jai   23     wgl
# 1  princi   34     hyd
# 2   guarv   54    krmg
# 3      av   54     viy

# %%
df2['Name']!='guarv'
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: Name, dtype: bool

# %%
df2[df2['Name']!='guarv']
# Out:
#      Name  age address
# 0     jai   23     wgl
# 1  princi   34     hyd
# 3      av   54     viy

# %%
(df['department']=='HR') & (df['city']== 'Mumbai')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df[(df['department']=='HR') & (df['city']== 'Mumbai')]
# Out:
#    emp_id   name department salary   join_date    city
# 0     101  Alice         HR  52000  2022-03-15  Mumbai

# %%
df[(df['department']=='HR') | (df['city']== 'Mumbai')]
# Out:
#    emp_id     name department salary   join_date    city
# 0     101    Alice         HR  52000  2022-03-15  Mumbai
# 2     103  Charlie       Tech    NaN  2020-11-20  Mumbai
# 3     104    Diana         HR  48000         NaN   Delhi

# %%
df[(df['department']!="HR")]
# Out:
#    emp_id     name department        salary   join_date       city
# 1     102      Bob       Tech         85000  2021-07-01       Pune
# 2     103  Charlie       Tech           NaN  2020-11-20     Mumbai
# 4     105      Eve    Finance         73000  2023-01-10        NaN
# 5     106      bob       Tech         85000  2021-07-01       Pune
# 6     107    Frank       Tech  not_a_number  2022-06-01  Bangalore

# %%
df[(df['department'].isin(['HR','Finance']))]
# Out:
#    emp_id   name department salary   join_date    city
# 0     101  Alice         HR  52000  2022-03-15  Mumbai
# 3     104  Diana         HR  48000         NaN   Delhi
# 4     105    Eve    Finance  73000  2023-01-10     NaN

# %%
df[~(df['department'].isin(['HR','Finance']))]
# Out:
#    emp_id     name department        salary   join_date       city
# 1     102      Bob       Tech         85000  2021-07-01       Pune
# 2     103  Charlie       Tech           NaN  2020-11-20     Mumbai
# 5     106      bob       Tech         85000  2021-07-01       Pune
# 6     107    Frank       Tech  not_a_number  2022-06-01  Bangalore

# %% [markdown]
# Sorting

# %%
df2.sort_values('age')
# Out:
#      Name  age address
# 0     jai   23     wgl
# 1  princi   34     hyd
# 2   guarv   54    krmg
# 3      av   54     viy

# %%
df2.sort_values('age',ascending=False)
# Out:
#      Name  age address
# 3      av   54     viy
# 2   guarv   54    krmg
# 1  princi   34     hyd
# 0     jai   23     wgl
